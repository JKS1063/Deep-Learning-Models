# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('customer_churn.csv')

# %%
df.head()
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# 0  No phone service             DSL             No  ...               No
# 1                No             DSL            Yes  ...              Yes
# 2                No             DSL            Yes  ...               No
# 3  No phone service             DSL            Yes  ...              Yes
# 4                No     Fiber optic             No  ...               No
#
# ...

# %%
df.shape
# Out:
# (7043, 21)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7043 non-null   object
#  1   gender            7043 non-null   object
#  2   SeniorCitizen     7043 non-null   int64
#  3   Partner           7043 non-null   object
#  4   Dependents        7043 non-null   object
#  5   tenure            7043 non-null   int64
#  6   PhoneService      7043 non-null   object
#  7   MultipleLines     7043 non-null   object
#  8   InternetService   7043 non-null   object
#  9   OnlineSecurity    7043 non-null   object
#  10  OnlineBackup      7043 non-null   object
#  11  DeviceProtection  7043 non-null   object
#  12  TechSupport       7043 non-null   object
#  13  StreamingTV       7043 non-null   object
#  14  StreamingMovies   7043 non-null   object
#  15  Contract          7043 non-null   object
# ...

# %%
df.TotalCharges = df.TotalCharges.str.strip(' ') # Removing empty spaces

# %%
df.TotalCharges = df.TotalCharges.replace('', None) # Replacing empty strings with None

# %%
df = df.replace('', None) # Replacing empty string with None for entire dataframe

# %%
df.TotalCharges.isnull().sum() # Checking null values
# Out:
# 11

# %%
df = df.fillna(df.bfill()) # Replacing null values with backfill

# %%
df.TotalCharges = df.TotalCharges.astype('float64')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7043 non-null   object
#  1   gender            7043 non-null   object
#  2   SeniorCitizen     7043 non-null   int64
#  3   Partner           7043 non-null   object
#  4   Dependents        7043 non-null   object
#  5   tenure            7043 non-null   int64
#  6   PhoneService      7043 non-null   object
#  7   MultipleLines     7043 non-null   object
#  8   InternetService   7043 non-null   object
#  9   OnlineSecurity    7043 non-null   object
#  10  OnlineBackup      7043 non-null   object
#  11  DeviceProtection  7043 non-null   object
#  12  TechSupport       7043 non-null   object
#  13  StreamingTV       7043 non-null   object
#  14  StreamingMovies   7043 non-null   object
#  15  Contract          7043 non-null   object
# ...

# %% [markdown]
# ### A. Data manipulation

# %% [markdown]
# #### a. Find the total number of male customers

# %%
df.head()
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# 0  No phone service             DSL             No  ...               No
# 1                No             DSL            Yes  ...              Yes
# 2                No             DSL            Yes  ...               No
# 3  No phone service             DSL            Yes  ...              Yes
# 4                No     Fiber optic             No  ...               No
#
# ...

# %%
male_cust = df.gender[df.gender == 'Male'].count()
print(f"{male_cust} male customers are there")
# Out:
# 3555 male customers are there

# %% [markdown]
# #### b. Find the total number of customers whose Internet Service is ‘DSL’

# %%
dsl_cust = df.InternetService[df.InternetService == 'DSL'].count()
print(f"{dsl_cust} customers using Internet Service as DSL")
# Out:
# 2421 customers using Internet Service as DSL

# %% [markdown]
# #### c. Extract all the Female senior citizens whose Payment Method is Mailed check & store the result in ‘new_customer’

# %%
new_customer = df[(df.gender == 'Female') & (df.SeniorCitizen == 1) & (df.PaymentMethod == 'Mailed check')]
print(f"{new_customer.shape[0]} female senior citizens are using Payment method as Mailed Check")
new_customer
# Out:
# 50 female senior citizens are using Payment method as Mailed Check
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 139   0390-DCFDQ  Female              1     Yes         No       1
# 176   2656-FMOKZ  Female              1      No         No      15
# 267   3197-ARFOY  Female              1      No         No      19
# 451   5760-WRAHC  Female              1      No         No      22
# 470   4933-IKULF  Female              1      No         No      17
# 694   2682-KEVRP  Female              1      No         No      22
# 747   3966-HRMZA  Female              1      No         No       3
# 947   9904-EHEVJ  Female              1     Yes        Yes      32
# 1029  4184-TJFAN  Female              1     Yes        Yes       3
# 1112  2176-LVPNX  Female              1      No         No      71
# 1513  0661-XEYAN  Female              1      No         No       1
# 1811  2070-XYMFH  Female              1      No         No      23
# ...

# %% [markdown]
# #### d. Extract all those customers whose tenure is less than 10 months or their Total charges is less than 500 dollars & store the result in ‘new_customer’

# %%
new_customer = df[(df.tenure < 10) | (df.TotalCharges < 500)]
print(f"{new_customer.shape[0]} customeres whose tenure is less than 10 months or their Total charges is less than 500 dollars")
new_customer
# Out:
# 2233 customeres whose tenure is less than 10 months or their Total charges is less than 500 dollars
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 0     7590-VHVEG  Female              0     Yes         No       1
# 2     3668-QPYBK    Male              0      No         No       2
# 4     9237-HQITU  Female              0      No         No       2
# 5     9305-CDSKC  Female              0      No         No       8
# 7     6713-OKOMC  Female              0      No         No      10
# ...          ...     ...            ...     ...        ...     ...
# 7029  2235-DWLJU  Female              1      No         No       6
# 7030  0871-OPBXW  Female              0      No         No       2
# 7032  6894-LFHLY    Male              1      No         No       1
# 7040  4801-JZAZL  Female              0     Yes        Yes      11
# 7041  8361-LTMKD    Male              1     Yes         No       4
#
# ...

# %% [markdown]
# ### B. Data Visualization

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# #### a. Build a pie-chart to show the distribution of customers would be churning out

# %%
churn = df.Churn[df.Churn == 'Yes'].count()
no_churn = df.Churn[df.Churn == 'No'].count()

pie = [churn, no_churn]
my_labels = ['Churned', 'Not Churned']
my_colors = ['orange', 'lime']

plt.figure(figsize = (8,8))
plt.pie(pie, labels = my_labels, colors = my_colors, 
        startangle = 90, autopct = '%.1f%%')
plt.title('Customer Churn Rate', fontweight = 'bold')
plt.legend(loc = 'upper right')

print(f"{churn} customers churned \n{no_churn} customers not churned")

plt.show()
# Out:
# 1869 customers churned
# 5174 customers not churned

# %% [markdown]
# #### b. Build a bar-plot to show the distribution of ‘Internet Service’

# %%
services = len(np.unique(df.InternetService))
services
# Out:
# 3

# %%
x = list(df.InternetService.value_counts().keys())
y = df.InternetService.value_counts()

plt.figure(figsize = (8, 6))
plt.title('Distributed Internet Service', fontweight = 'bold')
plt.xlabel('Internet Services', fontweight = 'bold')
plt.ylabel('Customer Count', fontweight = 'bold')
plt.bar(x, y, color = 'deepskyblue')
for index, value in enumerate(list(y)):
    plt.text(index, value, str(value), fontweight = 'bold')
    
plt.show()

# %% [markdown]
# * Above graph shows that there **3096** customers using **Fiber Optic** Internet Service.
# * **2421** Customers using **DSL** Internet Service
# * **1526** Customers have **No** Internet Service

# %% [markdown]
# ## C. Model Building

# %%
import livelossplot
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder, StandardScaler
from sklearn.metrics import confusion_matrix

from keras.layers import Dense, Dropout
from keras.models import Sequential
import tensorflow as tf

# %%
le = LabelEncoder()
df.Churn = le.fit_transform(df.Churn)

# %%
sc = StandardScaler()

# %%
plot_loss = livelossplot.PlotLossesKeras()

# %% [markdown]
# #### a. Build a sequential model using Keras, to find out if the customerwouldchurn or not, using‘tenure’ as the feature and ‘Churn’ as the dependent/target column:
# * i. The visible/input layer should have 12 nodes with ‘Relu’ as activation function.
# * ii. This model would have 1 hidden layer with 8 nodes and ‘Relu’ as activation function
# * iii. Use ‘Adam’ as the optimization algorithm
# * iv. Fit the model on the train set, with number of epochs to be 150
# * v. Predict the values on the test set and build a confusion matrix
# * vi. Plot the ‘Accuracy vs Epochs’ graph

# %%
x1 = df[['tenure']]
y1 = df['Churn']

# %%
x1_train, x1_test, y1_train, y1_test = train_test_split(x1, y1, test_size = 0.2, shuffle = True, random_state = 42)

# %%
x1_train = sc.fit_transform(x1_train)
x1_test = sc.fit_transform(x1_test)

# %%
shape1 = x1_train.shape[1]

# %%
model1 = Sequential()

model1.add(Dense(12, activation = 'relu', name = 'Input_Layer', input_shape = (shape1, )))
model1.add(Dense(8, activation = 'relu', name = 'Hidden_Layer'))
model1.add(Dense(1, activation = 'sigmoid', name = 'Output_Layer'))

model1.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  Input_Layer (Dense)         (None, 12)                24
#
#  Hidden_Layer (Dense)        (None, 8)                 104
#
#  Output_Layer (Dense)        (None, 1)                 9
#
# ...
# Total params: 137 (548.00 Byte)
# Trainable params: 137 (548.00 Byte)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
model1.compile(loss = 'binary_crossentropy', optimizer = 'adam', metrics = ['accuracy'])

# %%
x1_train.shape, y1_train.shape
# Out:
# ((5634, 1), (5634,))

# %%
history1 = model1.fit(x1_train, y1_train,
          epochs = 150,
          callbacks = [plot_loss],
          verbose = 0,
          validation_data = (x1_test, y1_test))
# Out:
# accuracy
# 	training         	 (min:    0.645, max:    0.756, cur:    0.753)
# 	validation       	 (min:    0.735, max:    0.757, cur:    0.757)
# Loss
# 	training         	 (min:    0.508, max:    0.638, cur:    0.509)
# 	validation       	 (min:    0.497, max:    0.547, cur:    0.500)

# %%
score = model1.evaluate(x1_test, y1_test, verbose = 0)
print('Test Loss:', round(score[0], 2))
print('Test Accuracy:', round(score[1], 2))
# Out:
# Test Loss: 0.5
# Test Accuracy: 0.76

# %%
y1_pred = model1.predict(x1_test)
# Out:
# 45/45 [==============================] - 0s 716us/step

# %%
y1_pred
# Out:
# array([[0.51690567],
#        [0.19847474],
#        [0.16249557],
#        ...,
#        [0.25511554],
#        [0.06348357],
#        [0.51690567]], dtype=float32)

# %%
y1_pred = np.round(y1_pred)

# %%
cm = confusion_matrix(y1_test, y1_pred)
sns.heatmap(cm, annot = True, cmap = 'coolwarm', fmt = 'g')
# Out:
# <Axes: >

# %%
epochs = 150
plt.plot(history1.history['accuracy'], label = 'Accuracy')
plt.plot(history1.history['val_accuracy'], label = 'Validation_Accuracy')
plt.xticks(np.arange(0, epochs, 10))
plt.legend(loc = 'upper right')
plt.show()

# %% [markdown]
# #### b. Build the 2nd model using same target and feature variables:
# * i. Add a drop-out layer after the input layer with drop-out value of 0.3
# * ii. Add a drop-out layer after the hidden layer with drop-out value of 0.2
# * iii. Predict the values on the test set and build a confusion matrix
# * iv. Plot the ‘Accuracy vs Epochs’ graph

# %%
x2 = df[['tenure']]
y2 = df['Churn']

x2_train, x2_test, y2_train, y2_test = train_test_split(x2 ,y2, test_size = 0.3, shuffle = True, random_state = 42)

x2_train = sc.fit_transform(x2_train)
x2_test = sc.fit_transform(x2_test)

shape2 = x2_train.shape[1]

# %%
model2 = Sequential()

model2.add(Dense(12, activation = 'relu', name = 'Input_Layer', input_shape = (shape2,)))
model2.add(Dropout(0.3))
model2.add(Dense(8, activation = 'relu', name = 'Hidden_Layer'))
model2.add(Dropout(0.2))
model2.add(Dense(1, activation = 'sigmoid', name = 'Output_Layer'))

model2.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  Input_Layer (Dense)         (None, 12)                24
#
#  dropout (Dropout)           (None, 12)                0
#
#  Hidden_Layer (Dense)        (None, 8)                 104
#
#  dropout_1 (Dropout)         (None, 8)                 0
#
#  Output_Layer (Dense)        (None, 1)                 9
#
# ...
# Total params: 137 (548.00 Byte)
# Trainable params: 137 (548.00 Byte)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
model2.compile(loss = 'binary_crossentropy',
               optimizer = 'adam',
               metrics = ['accuracy'])

# %%
history2 = model2.fit(x2_train, y2_train,
           epochs = 150,
           callbacks = [plot_loss],
           verbose = 0,
           validation_data = (x2_test, y2_test))
# Out:
# accuracy
# 	training         	 (min:    0.607, max:    0.756, cur:    0.743)
# 	validation       	 (min:    0.727, max:    0.757, cur:    0.727)
# Loss
# 	training         	 (min:    0.508, max:    0.684, cur:    0.515)
# 	validation       	 (min:    0.497, max:    0.634, cur:    0.513)

# %%
score2 = model2.evaluate(x2_test, y2_test)
print('Test Loss:', round(score2[0], 2))
print('Test Accuracy:', round(score2[1], 2))
# Out:
# 67/67 [==============================] - 0s 716us/step - loss: 0.5130 - accuracy: 0.7269
# Test Loss: 0.51
# Test Accuracy: 0.73

# %%
y2_pred = model2.predict(x2_test)
y2_pred = np.round(y2_pred)
y2_pred
# Out:
# 67/67 [==============================] - 0s 667us/step
# array([[0.],
#        [0.],
#        [0.],
#        ...,
#        [0.],
#        [0.],
#        [0.]], dtype=float32)

# %%
cm2 = confusion_matrix(y2_test, y2_pred)
sns.heatmap(cm2, annot = True, cmap = 'coolwarm', fmt = 'g')
plt.show()

# %%
plt.plot(history2.history['accuracy'], label = 'Accuracy')
plt.plot(history2.history['val_accuracy'], label = 'Validation Accuracy')
plt.xticks(np.arange(0, epochs, 10))
plt.legend(loc = 'upper right')
plt.show()

# %% [markdown]
# #### c. Build the 3rd model using ‘Tenure’, ’Monthly Charges’ & ‘Total Charges’ as the features and ‘Churn’ as the dependent/target column:
# * i. The visible/input layer should have 12 nodes with ‘Relu’ as activation function.
# * ii. This model would have 1 hidden layer with 8 nodes and ‘Relu’ as activation function
# * iii. Use ‘Adam’ as the optimization algorithm
# * iv. Fit the model on the train set, with number of epochs to be 150
# * v. Predict the values on the test set and build a confusion matrix
# * vi. Plot the ‘Accuracy vs Epochs’ graph

# %%
df.columns
# Out:
# Index(['customerID', 'gender', 'SeniorCitizen', 'Partner', 'Dependents',
#        'tenure', 'PhoneService', 'MultipleLines', 'InternetService',
#        'OnlineSecurity', 'OnlineBackup', 'DeviceProtection', 'TechSupport',
#        'StreamingTV', 'StreamingMovies', 'Contract', 'PaperlessBilling',
#        'PaymentMethod', 'MonthlyCharges', 'TotalCharges', 'Churn'],
#       dtype='object')

# %%
x3 = df[['tenure', 'MonthlyCharges', 'TotalCharges']]

# %%
y3 = df.Churn

# %%
x3_train, x3_test, y3_train, y3_test = train_test_split(x3, y3, test_size = 0.3, shuffle = True, random_state = 42)

# %%
x3_train = sc.fit_transform(x3_train)
x3_test = sc.fit_transform(x3_test)

# %%
shape3 = x3_train.shape[1]

# %%
model3 = Sequential()

model3.add(Dense(12, activation = 'relu', name = 'Input_Layer', input_shape = (shape3, )))
model3.add(Dense(8, activation = 'relu', name = 'Hidden_Layer'))
model3.add(Dense(1, activation = 'sigmoid'))

model3.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  Input_Layer (Dense)         (None, 12)                48
#
#  Hidden_Layer (Dense)        (None, 8)                 104
#
#  dense (Dense)               (None, 1)                 9
#
# ...
# Total params: 161 (644.00 Byte)
# Trainable params: 161 (644.00 Byte)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
model3.compile(loss = 'binary_crossentropy',
               optimizer = 'adam',
               metrics = ['accuracy'])

# %%
history3 = model3.fit(x3_train, y3_train,
                      epochs = 150,
                      callbacks = [plot_loss],
                      verbose = 0,
                      validation_data = (x3_test, y3_test))
# Out:
# accuracy
# 	training         	 (min:    0.607, max:    0.795, cur:    0.795)
# 	validation       	 (min:    0.727, max:    0.797, cur:    0.792)
# Loss
# 	training         	 (min:    0.444, max:    0.684, cur:    0.444)
# 	validation       	 (min:    0.435, max:    0.634, cur:    0.436)

# %%
score3 = model3.evaluate(x3_test, y3_test)
print('Test Loss:', round(score3[0], 2))
print('Test Accuracy:', round(score3[1], 2))
# Out:
# 67/67 [==============================] - 0s 790us/step - loss: 0.4364 - accuracy: 0.7922
# Test Loss: 0.44
# Test Accuracy: 0.79

# %%
y3_pred = model3.predict(x3_test)
y3_pred = np.round(y3_pred)
y3_pred
# Out:
# 67/67 [==============================] - 0s 659us/step
# array([[0.],
#        [0.],
#        [0.],
#        ...,
#        [0.],
#        [0.],
#        [0.]], dtype=float32)

# %%
np.unique(y3_pred)
# Out:
# array([0., 1.], dtype=float32)

# %%
cm = confusion_matrix(y3_test, y3_pred)
sns.heatmap(cm, annot = True, fmt = 'g', cmap = 'coolwarm')
plt.show()

# %%
plt.plot(history3.history['accuracy'], label = 'Accuracy')
plt.plot(history3.history['val_accuracy'], label = 'Validation Accuracy')
plt.xticks(np.arange(0, epochs, 10))
plt.legend(loc = 'upper right')
plt.show()
